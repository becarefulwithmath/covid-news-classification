# %%
#!/us bbbr/bin/env python

#for search
from googlesearch import search
import csv
import random
import datetime
query_suffix = " (coronavirus | covid | pandemic)"

#add article text1
from newspaper import Article

#add article text2
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True
def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

#file creation
now = datetime.datetime.now()
name = now.strftime("%m%d%Y%H%M%S")
file_name = "output_google" + name + ".csv"
print(file_name) 
with open(file_name, "a", newline='') as w:
            writer = csv.writer(w)
            row = ["query_id", "query", "result position", "url", "article_text1", "article_text2"]
            print(row)
            writer.writerow(row)

#array with search queries
array_of_q = []
with open("Keywords - Sample.csv", "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        array_of_q.append(row[1]+query_suffix)
print(array_of_q)

#search and results write
num_id = 1
for i in array_of_q:
    num = 0
    for url in search(i, tld='com', lang='en', stop=5, pause=random.randint(1,3)):
        num += 1
        with open(file_name, "a", newline='', encoding='utf-8') as w:
            writer = csv.writer(w)
                #get article text1
            article = Article(url)
            article.download()
            article.html
            article.parse()
                #get article text2
            html = urllib.request.urlopen(url).read()
                #write results
            row = [str(num_id), str(i), str(num), str(url), str(article.text),str(text_from_html(html))]
            #print(row)
            writer.writerow(row)
    num_id += 1
    print(str(len(array_of_q)+1-(num_id))+' remained')
# Out:
# output_google06292020143657.csv
# ['query_id', 'query', 'result position', 'url', 'article_text1', 'article_text2']
# ['it is more risky (coronavirus | covid | pandemic)', 'it is more riskier (coronavirus | covid | pandemic)']
# 1 remained
# 0 remained

# %%
# Out:
# Search Input Sections Sections Democracy Dies in Darkness Sign in Sign in Coronavirus outbreak Voraciously • Perspective I was anxious to go back to a restaurant. But once I did, I remembered the ... Travel As summer gets underway, a look at this year’s 10 best U.S. cities for park... Wellness Go ahead and watch. Cute or funny animal videos can be good for you. National Live updates: Texas, Florida pause reopening plans; new coronavirus cases h... NFL Saints’ Malcolm Jenkins: NFL a ‘nonessential business’ that must minimize c... Health Almost one-third of black Americans know someone who died of covid-19, surv... Business Governments eye new taxes on cigarettes, homes and tech giants to pay for b... NFL Tom Brady’s unofficial Bucs practices lead to questions for NFL In Sight • Perspective Intensely personal images show how a Bangladeshi family copes during the co... Europe How France’s skittishness about collecting data on race affects its coronav... Today's WorldView • Analysis Latin America’s coronavirus crisis is only getting worse National Live updates: U.S. sets another single-day record for new coronavirus cases Health CDC chief says coronavirus cases may be 10 times higher than reported The Fix • Analysis Some Republicans are choosing rosy assessments, as the full coronavirus pic... Maryland Politics Montgomery County can keep giving emergency funding to undocumented residen... Economic Policy Treasury sent more than 1 million coronavirus stimulus payments to dead peo... Sports The Marine Corps Marathon is still on (for now). But there will be less tim... Health How Arizona ‘lost control of the epidemic’ National Reopenings, record cases and full hospitals: America’s dissonant response t... Home Share Democracy Dies in Darkness Skip to main content Coronavirus Live updates  U.S. map  World map  Reopening tracker  Lives lost  Your life at home  Extraordinary people  Live Updates Live updates: Texas, Florida pause reopening plans; new coronavirus cases hit single-day record in U.S. By Katie Shepherd ,  Katie Shepherd Morning Mix reporter Email Bio Follow Jennifer Hassan ,  Jennifer Hassan Social media editor for the foreign desk Email Bio Follow Rick Noack ,  Rick Noack Foreign affairs reporter focusing on Europe and international security Email Bio Follow John Wagner ,  John Wagner National reporter on The Post's breaking political news team Email Bio Follow Katie Mettler ,  Katie Mettler Reporter covering breaking news and features Email Bio Follow Derek Hawkins ,  Derek Hawkins National and breaking news reporter Email Bio Follow Miriam Berger and  Miriam Berger Reporter covering Middle East, Foreign Affairs Email Bio Follow Kim Bellware  Kim Bellware Reporter covering national breaking news and features Email Bio Follow June 26, 2020 at 7:50 AM EDT Refresh for updates Please Note The Washington Post is providing this important information about the coronavirus for free. For more free coverage of the coronavirus pandemic, sign up for our Coronavirus Updates newsletter where all stories are free to read. As new coronavirus infections and hospitalizations soared to alarming new levels across the United States , the governors of several hard-hit states — including Texas, Florida and Arizona — paused their reopening plans. Nationally, 39,327 new infections were reported by state health departments Thursday, surpassing the previous record set just one day earlier. Texas alone reported a record 5,996 new cases (along with a record high for coronavirus hospitalizations), and the state’s rolling average has jumped by 340 percent since Memorial Day. “Literally, there’s been an explosion in the number of covid-19 patients,” Texas Gov. Greg Abbott (R) told a Lubbock TV station, noting that the “massive increase in spread” has struck small communities and big cities alike. Houston in particular faces a mounting crisis at hospitals, where intensive care unit beds are filling fast. Here are some significant developments: Centers for ...
